# %% [markdown]
# <a href="https://colab.research.google.com/github/nnilayy/Recurrent-Neural-Networks/blob/main/perfect_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import gc

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import roc_auc_score

import numpy as np
import pandas as pd

from tqdm import tqdm
tqdm.pandas()

from keras.models import Sequential
from keras.layers import Dense
# measure roc auc score metric 
from tensorflow.keras.metrics import AUC

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
train_terms=pd.read_csv('/content/drive/MyDrive/CAFA_PROTEIN_FUNCTION/Train/train_terms.tsv',sep='\t')
# train_terms.head(50)

# %%
train_terms.head()
# Out:
#       EntryID        term aspect
# 0  A0A009IHW8  GO:0008152    BPO
# 1  A0A009IHW8  GO:0034655    BPO
# 2  A0A009IHW8  GO:0072523    BPO
# 3  A0A009IHW8  GO:0044270    BPO
# 4  A0A009IHW8  GO:0006753    BPO

# %%
total=train_terms['term'].value_counts().sum()
classes=train_terms['term'].value_counts()
classes_percent=classes/total*100
classes_percent[:1000].sum()
# Out:
# 77.28622077036644

# %%
classes_percent=pd.DataFrame(classes_percent)
classes_percent.
# Out:
#                 term
# GO:0005575  1.732184
# GO:0008150  1.719097
# GO:0110165  1.701870
# GO:0003674  1.466052
# GO:0005622  1.319665
# ...              ...
# GO:0031772  0.000019
# GO:0042324  0.000019
# GO:0031771  0.000019
# GO:0051041  0.000019
# GO:0102628  0.000019
#
# [31466 rows x 1 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x=classes_percent["term"])
plt.show()

# %%
# Out:
#              term
# GO:0005575  92912
# GO:0008150  92210
# GO:0110165  91286
# GO:0003674  78637
# GO:0005622  70785
# ...           ...
# GO:0031772      1
# GO:0042324      1
# GO:0031771      1
# GO:0051041      1
# GO:0102628      1
#
# [31466 rows x 1 columns]

# %%
92912/5363863*100

# %%
term_frequency=pd.DataFrame(train_terms['term'].value_counts())
term_frequency.reset_index(level=0, inplace=True)
term_frequency=term_frequency.rename(columns={'index':'Terms','term': 'Frequency'})
term_frequency=term_frequency[:1500]
term_frequency.head()
# Out:
#         Terms  Frequency
# 0  GO:0005575      92912
# 1  GO:0008150      92210
# 2  GO:0110165      91286
# 3  GO:0003674      78637
# 4  GO:0005622      70785

# %%
train_terms=train_terms[train_terms['term'].isin(term_frequency['Terms'])]
train_terms=train_terms.reset_index(drop=True)
train_terms
# Out:
#             EntryID        term aspect
# 0        A0A009IHW8  GO:0008152    BPO
# 1        A0A009IHW8  GO:0034655    BPO
# 2        A0A009IHW8  GO:0044270    BPO
# 3        A0A009IHW8  GO:0006753    BPO
# 4        A0A009IHW8  GO:0044237    BPO
# ...             ...         ...    ...
# 4420732      X5L565  GO:0003674    MFO
# 4420733      X5L565  GO:0016491    MFO
# 4420734      X5M5N0  GO:0005515    MFO
# 4420735      X5M5N0  GO:0005488    MFO
# 4420736      X5M5N0  GO:0003674    MFO
#
# [4420737 rows x 3 columns]

# %%
train_ids=np.load('/content/drive/MyDrive/t5embeds/train_ids.npy')
train_ids=pd.DataFrame(train_ids)
train_ids
# .value_counts()
# Out:
#                  0
# 0           P20536
# 1           O73864
# 2           O95231
# 3       A0A0B4J1F4
# 4           P54366
# ...            ...
# 142241  A0A286YAI0
# 142242  A0A1D5NUC4
# 142243      Q5RGB0
# 142244  A0A2R8QMZ5
# 142245  A0A8I6GHU0
#
# [142246 rows x 1 columns]

# %%
train_embeds=np.load('/content/drive/MyDrive/t5embeds/train_embeds.npy')
train_embeds=pd.DataFrame(train_embeds)
train_embeds['1024']=train_ids[0]
train_embeds=train_embeds.set_index('1024')
train_embeds = train_embeds.rename(index={'1024': 'EntryID'})
train_embeds=train_embeds.rename_axis('EntryID')
train_embeds=train_embeds.reset_index(level=0)
train_embeds.head()
# Out:
#       EntryID         0         1         2         3         4         5  \
# 0      P20536  0.049488 -0.032935  0.032473 -0.033723 -0.059505  0.075936
# 1      O73864 -0.044616  0.064925 -0.080263 -0.075338 -0.004731  0.025408
# 2      O95231 -0.020128 -0.049779  0.007894 -0.000829 -0.047737  0.086453
# 3  A0A0B4J1F4 -0.007515  0.060628  0.004045  0.027056 -0.021542  0.010380
# 4      P54366  0.013468  0.041516  0.018435 -0.035595  0.008770  0.018699
#
#           6         7         8  ...      1014      1015      1016      1017  \
# 0 -0.045860 -0.104476 -0.072112  ... -0.046516 -0.028773 -0.021878 -0.097883
# 1 -0.024685 -0.016568 -0.038980  ... -0.040173  0.003925  0.006130  0.007362
# 2 -0.038107 -0.036379  0.029611  ...  0.029388  0.008456  0.000697  0.013502
# 3 -0.025064 -0.055834  0.068238  ...  0.020792  0.023307  0.009009  0.018211
# 4 -0.015452 -0.038092 -0.038326  ... -0.044742 -0.025432 -0.060886 -0.026915
#
#        1018      1019      1020      1021      1022      1023
# 0  0.056475  0.080950 -0.020938 -0.043532  0.096463  0.073070
# 1 -0.066848  0.106882 -0.030134  0.026724  0.027879 -0.048430
# 2 -0.005968 -0.011571  0.005704 -0.036103  0.007693  0.106234
# 3  0.020820 -0.031738  0.013279 -0.018357  0.008087  0.010917
# 4  0.026342  0.017237  0.014731 -0.016861 -0.016272  0.037054
#
# [5 rows x 1025 columns]

# %%
labels=train_terms.pivot(index ='EntryID', columns ='term',values='aspect')
labels.columns = [''.join(str(s).strip() for s in col if s) for col in labels.columns]
labels=labels.reset_index(level=0)
labels
# Out:
#            EntryID GO:0000003 GO:0000041 GO:0000070 GO:0000122 GO:0000139  \
# 0       A0A009IHW8        NaN        NaN        NaN        NaN        NaN
# 1       A0A021WW32        NaN        NaN        BPO        NaN        NaN
# 2       A0A021WZA4        NaN        NaN        NaN        NaN        NaN
# 3       A0A023FBW4        NaN        NaN        NaN        NaN        NaN
# 4       A0A023FBW7        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 142241      X6RKS3        NaN        NaN        NaN        NaN        NaN
# 142242      X6RLN4        NaN        NaN        NaN        NaN        NaN
# 142243      X6RLP6        NaN        NaN        NaN        NaN        NaN
# 142244      X6RLR1        NaN        NaN        NaN        NaN        NaN
# 142245      X6RM59        NaN        NaN        NaN        NaN        NaN
#
#        GO:0000151 GO:0000166 GO:0000226 GO:0000228  ... GO:2000112 GO:2000113  \
# 0             NaN        NaN        NaN        NaN  ...        NaN        NaN
# 1             NaN        NaN        NaN        CCO  ...        NaN        NaN
# 2             NaN        NaN        NaN        NaN  ...        NaN        NaN
# 3             NaN        NaN        NaN        NaN  ...        NaN        NaN
# 4             NaN        NaN        NaN        NaN  ...        NaN        NaN
# ...           ...        ...        ...        ...  ...        ...        ...
# 142241        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 142242        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 142243        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 142244        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 142245        NaN        NaN        NaN        NaN  ...        NaN        NaN
#
#        GO:2000145 GO:2000146 GO:2000147 GO:2000241 GO:2000243 GO:2001020  \
# 0             NaN        NaN        NaN        NaN        NaN        NaN
# 1             NaN        NaN        NaN        NaN        NaN        NaN
# 2             NaN        NaN        NaN        NaN        NaN        NaN
# 3             NaN        NaN        NaN        NaN        NaN        NaN
# 4             NaN        NaN        NaN        NaN        NaN        NaN
# ...           ...        ...        ...        ...        ...        ...
# 142241        NaN        NaN        NaN        NaN        NaN        NaN
# 142242        NaN        NaN        NaN        NaN        NaN        NaN
# 142243        NaN        NaN        NaN        NaN        NaN        NaN
# 142244        NaN        NaN        NaN        NaN        NaN        NaN
# 142245        NaN        NaN        NaN        NaN        NaN        NaN
#
#        GO:2001141 GO:2001233
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
# ...           ...        ...
# 142241        NaN        NaN
# 142242        NaN        NaN
# 142243        NaN        NaN
# 142244        NaN        NaN
# 142245        NaN        NaN
#
# [142246 rows x 1501 columns]

# %%
labels= labels.iloc[:, 0:].notnull().astype("int")
labels=labels.drop(columns=['EntryID'])
# labels

# %%
train_embeds=train_embeds.sort_values('EntryID')
train_embeds=train_embeds.reset_index(drop=True)
train_embeds=train_embeds.drop(columns=['EntryID'])
train_embeds.head()
# Out:
#        0         1         2         3         4         5         6     \
# 0  0.067778 -0.046573  0.001871 -0.008532  0.003735  0.046137 -0.059283
# 1 -0.016303 -0.001599  0.003910  0.073261  0.012426  0.028077 -0.040412
# 2  0.007994  0.087365 -0.001631  0.037468  0.017858  0.025504 -0.011703
# 3  0.002134  0.005902  0.064059  0.008222 -0.033212 -0.009141 -0.021793
# 4  0.048641  0.019926  0.107575  0.016752 -0.050425 -0.016805 -0.041421
#
#        7         8         9     ...      1014      1015      1016      1017  \
# 0 -0.049906 -0.005312  0.008608  ... -0.040293 -0.013106 -0.049407 -0.100177
# 1 -0.093539 -0.017918  0.025457  ...  0.011927 -0.033233 -0.031254 -0.005067
# 2 -0.084401 -0.016387 -0.034820  ...  0.004973 -0.049626 -0.027136 -0.037160
# 3 -0.082338 -0.004026 -0.018951  ... -0.052513 -0.002440 -0.015824 -0.067800
# 4 -0.151901  0.007275  0.029193  ... -0.099127 -0.062734  0.002741 -0.102748
#
#        1018      1019      1020      1021      1022      1023
# 0  0.066018  0.009035 -0.003596 -0.024547  0.034698 -0.030786
# 1  0.014727  0.081792  0.017501 -0.033023  0.053113  0.029803
# 2 -0.006266 -0.039532  0.001768  0.004620 -0.004204  0.001841
# 3  0.041472 -0.050621 -0.025166  0.056364  0.097354  0.032667
# 4 -0.000900 -0.046363  0.002974 -0.036701  0.102472  0.004925
#
# [5 rows x 1024 columns]

# %%
train_embeds.to_csv('/content/drive/MyDrive/CAFA_PROTEIN_FUNCTION/train_test_data/train_embeds.csv')

# %%
labels.to_csv('/content/drive/MyDrive/CAFA_PROTEIN_FUNCTION/train_test_data/labels.csv')

# %%
import gc
gc.collect()
# Out:
# 0

# %%
train_embeds=pd.read_csv('/content/drive/MyDrive/CAFA_PROTEIN_FUNCTION/train_test_data/train_embeds.csv')
labels=pd.read_csv('/content/drive/MyDrive/CAFA_PROTEIN_FUNCTION/train_test_data/labels.csv')

# %%
train_embeds=train_embeds.drop(columns=['Unnamed: 0'])
# train_embeds.head()

# %%
labels=labels.drop(columns=['Unnamed: 0'])
# labels.head()

# %%
test_ids=np.load('/content/drive/MyDrive/t5embeds/test_ids.npy')
test_ids=pd.DataFrame(test_ids)
# test_ids.head()

# %%
test_embeds=np.load('/content/drive/MyDrive/t5embeds/train_embeds.npy')
test_embeds=pd.DataFrame(test_embeds)
# test_embeds.head()

# %%
test_embeds=test_embeds.set_index(test_ids[0])
test_embeds = test_embeds.rename(index={'0': 'EntryID'})
test_embeds=test_embeds.rename_axis('EntryID')
test_embeds=test_embeds.reset_index(level=0)
# test_embeds.head()
# test_embeds.sort_values('EntryID')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-b385dedd35e0> in <cell line: 1>()
# ----> 1 test_embeds=test_embeds.set_index(test_ids[0])
#       2 test_embeds = test_embeds.rename(index={'0': 'EntryID'})
#       3 test_embeds=test_embeds.rename_axis('EntryID')
#       4 test_embeds=test_embeds.reset_index(level=0)
#       5 # test_embeds.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6060                 # check newest element against length of calling frame, since
#    6061                 # ensure_index_from_sequences would not raise for append=False.
# -> 6062                 raise ValueError(
#    6063                     f"Length mismatch: Expected {len(self)} rows, "
#    6064                     f"received array of length {len(arrays[-1])}"
#
# ValueError: Length mismatch: Expected 142246 rows, received array of length 141865

# %%
test_embeds=test_embeds.sort_values('EntryID')
test_embeds=test_embeds.reset_index(drop=True)
# test_embeds.head()

# %%
train_embeds=train_embeds.drop(columns=['EntryID'])
labels=labels.drop(columns=['EntryID'])

# %%
selected_terms=set(labels.columns)
print(selected_terms)

# %%
train_embeds=train_embeds.to_numpy()
labels=labels.to_numpy()

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train_embeds, labels, shuffle=True, random_state=42)

# %%
nfeats = x_train.shape[1]
nlabels = y_train.shape[1]
model = Sequential()
model.add(Dense(256, activation='relu', input_dim=nfeats))
model.add(Dense(128, activation='relu'))
model.add(Dense(nlabels, activation='sigmoid'))
model.summary()

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=[AUC()])
model.fit(x_train, y_train, epochs=15, batch_size=128, validation_data=(x_valid, y_valid))

# %%
model.save('model_ann.h5')

# %%
from tensorflow.keras.saving import load_model
model=load_model('/kaggle/input/model-ann/model_ann.h5')

# %%
y_hat = model.predict(x_valid)
scores = pd.DataFrame(columns=list(selected_terms), index=['roc_auc'])
for i, term in enumerate(selected_terms):
    score = roc_auc_score(y_valid[:, i], y_hat[:, i])
    scores[term] = score

scores.mean(axis=1)

# %%
y_valid[:, i]

# %%
test_ids = np.load('/kaggle/input/t5embeds/test_ids.npy')
x_test = np.load('/kaggle/input/t5embeds/test_embeds.npy')

# %%
del x_train, y_train, x_valid, y_valid, labels
gc.collect()

# %%
predictions = model.predict(x_test)
# del x_test
gc.collect()

chunk_size = 5_000
chunks = [range(i, min(i + chunk_size, len(predictions))) for i in range(0, len(predictions), chunk_size)]
final_sub = pd.DataFrame()  # Create an empty DataFrame to hold the final result
print(f"processing {len(chunks)} chunks of {chunk_size} predictions each")

for chunk in chunks:
    print(f"processing chunk {chunk}")
    sub = pd.DataFrame(data=predictions[chunk], columns=list(selected_terms), index=test_ids[chunk])
    sub = sub.T.unstack().reset_index(name='prediction')
    sub = sub.loc[sub['prediction'] > 0]
    final_sub = pd.concat([final_sub, sub])  # Concatenate current chunk DataFrame to the final DataFrame

final_sub.head()

# %%
final_sub.to_csv('submission.tsv', sep='\t', index=False, header=False)

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/CAFA_PROTEIN_FUNCTION/IA.txt", sep="\t",header=None, names=['GO Terms','Predictions'])
df=pd.DataFrame(df)
df
# Out:
#          GO Terms  Predictions
# 0      GO:0000001     0.000000
# 1      GO:0000002     3.103836
# 2      GO:0000003     3.439404
# 3      GO:0000011     0.056584
# 4      GO:0000012     6.400377
# ...           ...          ...
# 43243  GO:2001083     7.159871
# 43244  GO:2001084     7.592457
# 43245  GO:2001085     7.159871
# 43246  GO:2001147     5.554589
# 43247  GO:2001227     0.000000
#
# [43248 rows x 2 columns]

# %%
df[df['Predictions']>0]
# Out:
#          GO Terms  Predictions
# 1      GO:0000002     3.103836
# 2      GO:0000003     3.439404
# 3      GO:0000011     0.056584
# 4      GO:0000012     6.400377
# 5      GO:0000017     0.514573
# ...           ...          ...
# 43242  GO:2001082     7.159871
# 43243  GO:2001083     7.159871
# 43244  GO:2001084     7.592457
# 43245  GO:2001085     7.159871
# 43246  GO:2001147     5.554589
#
# [30267 rows x 2 columns]

# %%
# !pip install biopython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting biopython
#   Downloading biopython-1.81-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 34.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.22.4)
# Installing collected packages: biopython
# Successfully installed biopython-1.81

# %%
from Bio import SeqIO
records=[]
with open("/content/drive/MyDrive/CAFA_PROTEIN_FUNCTION/Train/train_sequences.fasta") as handle:
    for record in SeqIO.parse(handle, "fasta"):
      records.append(record)

# %%
sequences=[]
ids=[]
names=[]
descriptions=[]
dbxrefs=[]

for record in records:
  sequences.append(record.seq)
  ids.append(record.id)
  names.append(record.name)
  descriptions.append(record.description)
  dbxrefs.append(record.dbxrefs)

fasta_file={
    'Sequences':sequences,
    'IDs':ids,
    'names':names,
    'Descriptions':descriptions,
}
data=pd.DataFrame(fasta_file)
df=fasta=data

# %%
# datas=fasta['Descriptions']
# datas=pd.DataFrame(datas,columns=['Descriptions'])
# datas=datas.reset_index()
datas['index']

# %%
import re
id_regex = r'(\S+)'
sp_id_regex = r'([a-zA-Z]{2}\|[^\|]+\|)'
# r'sp\|([^|]+)\|'

desc_regex =r'([^=]+)'  
os_regex = r'OS=([^=]+)'
ox_regex = r'OX=([^=]+)'
gn_regex = r'GN=([^=]+)'
pe_regex = r'PE=(\d+)'
sv_regex = r'SV=(\d+)'

columns = []
indexes=[]
for i in range(len(data)):
  line = datas['Descriptions'][i]
  match = re.match(fr'{id_regex} {sp_id_regex}{desc_regex} {os_regex} {ox_regex} {gn_regex} {pe_regex} {sv_regex}', line)
  if match:
    columns.append(match.groups())
    indexes.append(datas['index'][i])
    

df1=pd.DataFrame(columns,columns=['EntryID','SP_Entry_id','Description','OS','OX','GN','PE','SV'])
df1.insert(0, 'Index', indexes)
df1
# Out:
#          Index     EntryID     SP_Entry_id  \
# 0            0      P20536      sp|P20536|
# 1            1      O73864      sp|O73864|
# 2            2      O95231      sp|O95231|
# 3            3  A0A0B4J1F4  sp|A0A0B4J1F4|
# 4            4      P54366      sp|P54366|
# ...        ...         ...             ...
# 138834  142241  A0A286YAI0  tr|A0A286YAI0|
# 138835  142242  A0A1D5NUC4  tr|A0A1D5NUC4|
# 138836  142243      Q5RGB0      tr|Q5RGB0|
# 138837  142244  A0A2R8QMZ5  tr|A0A2R8QMZ5|
# 138838  142245  A0A8I6GHU0  tr|A0A8I6GHU0|
#
#                                               Description  \
# 0                        UNG_VACCC Uracil-DNA glycosylase
# 1                              WNT11_DANRE Protein Wnt-11
# 2                      VENTX_HUMAN Homeobox protein VENTX
# 3        ARRD4_MOUSE Arrestin domain-containing protein 4
# 4                    GSC_DROME Homeobox protein goosecoid
# ...                                                   ...
# 138834  A0A286YAI0_DANRE Macrophage receptor with coll...
# 138835  A0A1D5NUC4_CHICK Mitogen-activated protein kin...
# 138836  Q5RGB0_DANRE Potassium channel, subfamily K, m...
# 138837       A0A2R8QMZ5_DANRE Myocyte enhancer factor 2aa
# 138838  A0A8I6GHU0_RAT U6 snRNA-associated Sm-like pro...
#
#                                         OS     OX      GN PE SV
# 0       Vaccinia virus (strain Copenhagen)  10249     UNG  1  1
# 1                              Danio rerio   7955   wnt11  2  1
# 2                             Homo sapiens   9606   VENTX  1  1
# 3                             Mus musculus  10090  Arrdc4  1  1
# 4                  Drosophila melanogaster   7227     Gsc  2  2
# ...                                    ...    ...     ... .. ..
# 138834                         Danio rerio   7955   marco  4  1
# 138835                       Gallus gallus   9031  MAP3K7  3  1
# 138836                         Danio rerio   7955  kcnk5b  3  1
# 138837                         Danio rerio   7955  mef2aa  4  1
# 138838                   Rattus norvegicus  10116    Lsm1  3  1
#
# [138839 rows x 9 columns]

# %%
# print(df1['Description'][88])
df1.iloc[1]
# Out:
# Index                                   1
# EntryID                            O73864
# SP_Entry_id                    sp|O73864|
# Description    WNT11_DANRE Protein Wnt-11
# OS                            Danio rerio
# OX                                   7955
# GN                                  wnt11
# PE                                      2
# SV                                      1
# Name: 1, dtype: object

# %%
missing=datas[datas['index'].isin(df1['Index'])==False]
missing
# Out:
# 'O76745 sp|O76745|NP_CIMLE Nitrophorin Cim l NP OS=Cimex lectularius OX=79782 PE=1 SV=1'

# %%
missing['Descriptions'][95]
# Out:
# 'A0A193H396 sp|A0A193H396|CZS6_CRUCA Cruzioseptin-6 OS=Cruziohyla calcarifer OX=318249 PE=1 SV=1'

# %%
datas['index']

# %%
for dat in data['Descriptions'][:-300]:
  print(dat)

# %%
Q9R172 sp|Q9R172|NOTC3_RAT Neurogenic locus notch homolog protein 3 OS=Rattus norvegicus OX=10116 GN=Notch3 PE=2 SV=2

# %%
import re
import pandas as pd

data = '''P20536 sp|P20536|UNG_VACCC Uracil-DNA glycosylase OX=10249 GN=UNG PE=1 SV=1
O73864 sp|O73864|WNT11_DANRE Protein Wnt-11 OS=Danio rerio GN=wnt11 PE=2 SV=1
O95231 xd|HJ0536|VENTX_HUMAN Homeobox protein VENTX GN=VENTX PE=1'''

id_regex = r'(\S+)'
sp_id_regex = r'([a-zA-Z]{2}\|[^\|]+\|)'
desc_regex = r'([^=]+)'
os_regex = r'OS=([^=]+)?'  # Make OS value optional
ox_regex = r'OX=([^=]+)?'  # Make OX value optional
gn_regex = r'GN=([^=]+)'
pe_regex = r'PE=(\d+)?'  # Make PE value optional
sv_regex = r'SV=(\d+)?'  # Make SV value optional

columns = []
lines = data.split('\n')
for line in lines:
    match = re.match(fr'{id_regex} {sp_id_regex}{desc_regex} {os_regex} {ox_regex} {gn_regex} {pe_regex} {sv_regex}', line)
    if match:
        columns.append(match.groups())

# Display the extracted information in separate columns
df = pd.DataFrame(columns, columns=['EntryID', 'SP_Entry_id', 'Description', 'OS', 'OX', 'GN', 'PE', 'SV'])
print(df)
# Out:
# Empty DataFrame
# Columns: [EntryID, SP_Entry_id, Description, OS, OX, GN, PE, SV]
# Index: []
